# %%
import pymongo 
from pymongo import MongoClient
import pandas as pd
import json

client = MongoClient("mongodb://Lori:Les4783!@ds223756.mlab.com:23756")

db = client["heroku_r58qkhd7"]
collection = db["listings_json"]

# %%
# df = pd.read_json("museums.json")
# df.head()

df = pd.read_json("neworleans_condensed.json")
df.head()
# Out:
#    accommodates bathrooms bedrooms beds host_name     id  latitude  \
# 0             4         2        3    3      Jill  10291  29.98666
# 1             3         1        1    1      John  19091  29.96257
# 2             2         1        1    1    Rachel  26834  29.96557
# 3             2         2        1    1     Karen  53173  29.96483
# 4             2         1        1    1       Lee  53544  29.96697
#
#                           listing_url  longitude  minimum_nights  \
# 0  https://www.airbnb.com/rooms/10291  -90.10928               2
# 1  https://www.airbnb.com/rooms/19091  -90.11877               1
# 2  https://www.airbnb.com/rooms/26834  -90.05531               4
# 3  https://www.airbnb.com/rooms/53173  -90.03906               3
# 4  https://www.airbnb.com/rooms/53544  -90.03068               5
#
#                                              name neighbourhood_cleansed  \
# 0                   Spacious Cottage in Mid-City!                Navarre
# ...

# %%
df.to_json(orient="records")
# collection.insert(file_data)
# Out:
# '[{"accommodates":4,"bathrooms":2,"bedrooms":3,"beds":3,"host_name":"Jill","id":10291,"latitude":29.98666,"listing_url":"https:\\/\\/www.airbnb.com\\/rooms\\/10291","longitude":-90.10928,"minimum_nights":2,"name":"Spacious Cottage in Mid-City!","neighbourhood_cleansed":"Navarre","price":300,"property_type":"Cottage","room_type":"Entire home\\/apt"},{"accommodates":3,"bathrooms":1,"bedrooms":1,"beds":1,"host_name":"John","id":19091,"latitude":29.96257,"listing_url":"https:\\/\\/www.airbnb.com\\/rooms\\/19091","longitude":-90.11877,"minimum_nights":1,"name":"Fully Furnished Cozy Apartment","neighbourhood_cleansed":"Leonidas","price":100,"property_type":"Apartment","room_type":"Entire home\\/apt"},{"accommodates":2,"bathrooms":1,"bedrooms":1,"beds":1,"host_name":"Rachel","id":26834,"latitude":29.96557,"listing_url":"https:\\/\\/www.airbnb.com\\/rooms\\/26834","longitude":-90.05531,"minimum_nights":4,"name":"Maison Mandeville in the Marigny","neighbourhood_cleansed":"Marigny","price":125
# ...

# %%
df.to_json("listings.json")

# %%
with open("listings.json") as f:
    file_data = json.load(f)
    collection.insert(file_data)
# Out:
# C:\Users\Dylan\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-37-d7475e665e2a> in <module>
#       1 with open("listings.json") as f:
#       2     file_data = json.load(f)
# ----> 3     collection.insert(file_data)
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in insert(self, doc_or_docs, manipulate, check_keys, continue_on_error, **kwargs)
#    3159             write_concern = WriteConcern(**kwargs)
#    3160         return self._insert(doc_or_docs, not continue_on_error,
# -> 3161                             check_keys, manipulate, write_concern)
#    3162
# ...
