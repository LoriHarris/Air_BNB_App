# %%
import pymongo 
from pymongo import MongoClient
import pandas as pd
import json

client = MongoClient("mongodb://Lori:Les4783!@ds223756.mlab.com:23756/heroku_r58qkhd7")

db = client["heroku_r58qkhd7"]
collection = db["model"]

# %%
    
from flask import Flask, render_template, redirect, jsonify, request
from flask_pymongo import PyMongo
import pandas as pd
import pymongo
from pymongo import MongoClient
import os
from bson.objectid import ObjectId
import pprint
import sys
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import geopy
from geopy import distance
from geopy.distance import vincenty
# from tqdm import tqdm
# tqdm.pandas()
import tensorflow as tf
from keras.utils import to_categorical
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import RandomizedSearchCV
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from collections import Counter
from scipy import stats
from dateutil import parser
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)
import numpy as np
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
# df = pd.read_json("museums.json")
# df.head()

df = pd.read_csv("test_data.csv")
df.head()

# %%
df.to_csv('hoods.csv')

# %%
df["Name"] = df["Name"].str.replace(".","")

df1 = df.set_index('Name')

# %%
df.to_json("test_data.json", orient="records")
# collection.insert(file_data)

# %%
df.to_json("test_data.json")

# %%
with open("test_data.json") as f:
    file_data = json.load(f)
    collection.insert(file_data)

# %%
with open("test_data.csv") as f:
    file_data = json.load(f)
#     print(file_data)
df = pd.read_json('hoods.json')
df.keys()

# %%
df = pd.read_json('test_data.json')
df.head()

# %%
listings = []
prediction=[]
# test1 = pd.DataFrame(prediction)

# myquery = {"Name":{ '$eq': ('Uptown Cottage') }}

myquery = {}
print('query', collection.find(myquery))
for json in collection.find(myquery):
    data = {}
    data.update({
    'MinNights': json['MinNights'],
    'Hood' : json['Hood'],
    'SqFt' : json['SqFt'],
    '#Reviews': json['#Reviews'],
    '#Guests' :json['#Guests'],
    'Listing Count' : json['Listing Count'],
    'Security':json['Security']      ,
    'CleanFee':json['CleanFee'],
    'Dist':json['Dist'],
    'BA':json['BA'],
    'BR':json['BR'],
    'Beds':json['Beds'],
    'Acc': json['Acc'],
    '#Booked':json['#Booked'],
    'Price':json['Price'],
    'Name':json['Name'],
                'Polarity':json['Polarity']

    })
    listings.append(data)
listings
# Out:
# query <pymongo.cursor.Cursor object at 0x00000192E5EDCC18>
# [{'MinNights': 1,
#   'Hood': 43,
#   'SqFt': 20,
#   '#Reviews': 95,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 69,
#   'Dist': 5069,
#   'BA': 4,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 4,
#   '#Booked': 98,
#   'Price': 3,
#   'Name': 'Spacious Cottage in Mid-City!',
#   'Polarity': 4601},
#  {'MinNights': 0,
#   'Hood': 33,
#   'SqFt': 15,
#   '#Reviews': 287,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 40,
#   'Dist': 4988,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 3,
#   '#Booked': 398,
#   'Price': 1,
#   'Name': 'Fully Furnished Cozy Apartment',
#   'Polarity': 4272},
#  {'MinNights': 3,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 214,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 18,
#   'CleanFee': 55,
#   'Dist': 1422,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 209,
#   'Price': 2,
#   'Name': 'Maison Mandeville in the Marigny',
#   'Polarity': 5192},
#  {'MinNights': 2,
#   'Hood': 54,
#   'SqFt': 20,
#   '#Reviews': 132,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 0,
#   'CleanFee': 48,
#   'Dist': 3255,
#   'BA': 4,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 131,
#   'Price': 1,
#   'Name': 'MARDI GRAS YA’LL HUNDREDS 5 STAR REVIEWS !!!',
#   'Polarity': 5279},
#  {'MinNights': 4,
#   'Hood': 6,
#   'SqFt': 20,
#   '#Reviews': 178,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 15,
#   'CleanFee': 34,
#   'Dist': 4128,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 175,
#   'Price': 0,
#   'Name': 'Historical Bywater Mother in Law Cottage',
#   'Polarity': 5326},
#  {'MinNights': 1,
#   'Hood': 2,
#   'SqFt': 7,
#   '#Reviews': 190,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 18,
#   'CleanFee': 55,
#   'Dist': 2481,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 192,
#   'Price': 2,
#   'Name': 'The Retreat in Lovely Bayou St John',
#   'Polarity': 5123},
#  {'MinNights': 2,
#   'Hood': 54,
#   'SqFt': 20,
#   '#Reviews': 200,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 55,
#   'Dist': 3522,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 206,
#   'Price': 2,
#   'Name': 'Ravenwood Manor (Historic Bywater)',
#   'Polarity': 5398},
#  {'MinNights': 2,
#   'Hood': 55,
#   'SqFt': 20,
#   '#Reviews': 289,
#   '#Guests': 1,
#   'Listing Count': 3,
#   'Security': 21,
#   'CleanFee': 23,
#   'Dist': 2012,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 454,
#   'Price': 1,
#   'Name': 'Maison Marais 1: Large Local Living',
#   'Polarity': 5314},
#  {'MinNights': 2,
#   'Hood': 6,
#   'SqFt': 20,
#   '#Reviews': 165,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 18,
#   'CleanFee': 16,
#   'Dist': 3504,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 223,
#   'Price': 1,
#   'Name': 'Luxury & history in the Big Easy #1',
#   'Polarity': 4751},
#  {'MinNights': 3,
#   'Hood': 51,
#   'SqFt': 20,
#   '#Reviews': 284,
#   '#Guests': 2,
#   'Listing Count': 1,
#   'Security': 15,
#   'CleanFee': 13,
#   'Dist': 2468,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 5,
#   '#Booked': 438,
#   'Price': 1,
#   'Name': 'SpaciousCleanFunctional Private Apt',
#   'Polarity': 3537},
#  {'MinNights': 2,
#   'Hood': 38,
#   'SqFt': 30,
#   '#Reviews': 26,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 55,
#   'Dist': 4720,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 31,
#   'Price': 1,
#   'Name': 'Beautiful Room Uptown Home - License 17STR-10083',
#   'Polarity': 2922},
#  {'MinNights': 2,
#   'Hood': 54,
#   'SqFt': 10,
#   '#Reviews': 251,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 40,
#   'Dist': 3468,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 289,
#   'Price': 1,
#   'Name': "Moon Over Mazant Bywater's First and Best!",
#   'Polarity': 5188},
#  {'MinNights': 0,
#   'Hood': 37,
#   'SqFt': 12,
#   '#Reviews': 302,
#   '#Guests': 1,
#   'Listing Count': 3,
#   'Security': 0,
#   'CleanFee': 5,
#   'Dist': 1187,
#   'BA': 4,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 598,
#   'Price': 1,
#   'Name': 'Frenchmen House "Red Room"',
#   'Polarity': 3943},
#  {'MinNights': 3,
#   'Hood': 57,
#   'SqFt': 20,
#   '#Reviews': 32,
#   '#Guests': 2,
#   'Listing Count': 2,
#   'Security': 55,
#   'CleanFee': 69,
#   'Dist': 5362,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 4,
#   '#Booked': 49,
#   'Price': 2,
#   'Name': 'NOLA Family Suite',
#   'Polarity': 1464},
#  {'MinNights': 2,
#   'Hood': 57,
#   'SqFt': 20,
#   '#Reviews': 30,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 44,
#   'CleanFee': 69,
#   'Dist': 5399,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 54,
#   'Price': 1,
#   'Name': 'NOLA Chateau',
#   'Polarity': 2754},
#  {'MinNights': 0,
#   'Hood': 59,
#   'SqFt': 12,
#   '#Reviews': 300,
#   '#Guests': 0,
#   'Listing Count': 4,
#   'Security': 8,
#   'CleanFee': 27,
#   'Dist': 855,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 575,
#   'Price': 1,
#   'Name': "NOLA'S STUDIO central to everything",
#   'Polarity': 3978},
#  {'MinNights': 1,
#   'Hood': 8,
#   'SqFt': 10,
#   '#Reviews': 4,
#   '#Guests': 0,
#   'Listing Count': 37,
#   'Security': 0,
#   'CleanFee': 0,
#   'Dist': 3271,
#   'BA': 1,
#   'BR': 0,
#   'Beds': 1,
#   'Acc': 4,
#   '#Booked': 5,
#   'Price': 3,
#   'Name': 'Historic UPTOWN NEW ORLEANS Resort',
#   'Polarity': 68},
#  {'MinNights': 2,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 270,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 0,
#   'CleanFee': 27,
#   'Dist': 913,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 355,
#   'Price': 2,
#   'Name': 'Marginy BnoB by Frenchman!',
#   'Polarity': 4865},
#  {'MinNights': 3,
#   'Hood': 40,
#   'SqFt': 20,
#   '#Reviews': 133,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 0,
#   'Dist': 4040,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 3,
#   '#Booked': 147,
#   'Price': 1,
#   'Name': 'Live Like a Local in Mid-City',
#   'Polarity': 5255},
#  {'MinNights': 3,
#   'Hood': 6,
#   'SqFt': 24,
#   '#Reviews': 100,
#   '#Guests': 2,
#   'Listing Count': 11,
#   'Security': 38,
#   'CleanFee': 88,
#   'Dist': 3079,
#   'BA': 4,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 105,
#   'Price': 2,
#   'Name': '5 Star Elegant Bywater Shotgun-Antiques-Monthly',
#   'Polarity': 4286},
#  {'MinNights': 0,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 296,
#   '#Guests': 1,
#   'Listing Count': 4,
#   'Security': 8,
#   'CleanFee': 30,
#   'Dist': 537,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 514,
#   'Price': 1,
#   'Name': "SHIRO'S SUITE - central & cute!",
#   'Polarity': 4090},
#  {'MinNights': 3,
#   'Hood': 6,
#   'SqFt': 20,
#   '#Reviews': 86,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 2,
#   'CleanFee': 55,
#   'Dist': 4245,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 90,
#   'Price': 0,
#   'Name': 'Historical Guest Room for Mardi Gras',
#   'Polarity': 4862},
#  {'MinNights': 0,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 293,
#   '#Guests': 0,
#   'Listing Count': 4,
#   'Security': 8,
#   'CleanFee': 30,
#   'Dist': 845,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 494,
#   'Price': 1,
#   'Name': "BUNNY'S suite, walk everywhere!",
#   'Polarity': 4415},
#  {'MinNights': 3,
#   'Hood': 54,
#   'SqFt': 20,
#   '#Reviews': 256,
#   '#Guests': 1,
#   'Listing Count': 3,
#   'Security': 18,
#   'CleanFee': 40,
#   'Dist': 2953,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 318,
#   'Price': 1,
#   'Name': 'True NaWlins Flavor',
#   'Polarity': 4493},
#  {'MinNights': 0,
#   'Hood': 59,
#   'SqFt': 12,
#   '#Reviews': 292,
#   '#Guests': 1,
#   'Listing Count': 4,
#   'Security': 8,
#   'CleanFee': 30,
#   'Dist': 678,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 499,
#   'Price': 1,
#   'Name': 'SHOGAS SUITE - close to everything',
#   'Polarity': 4276},
#  {'MinNights': 0,
#   'Hood': 37,
#   'SqFt': 12,
#   '#Reviews': 301,
#   '#Guests': 1,
#   'Listing Count': 3,
#   'Security': 0,
#   'CleanFee': 5,
#   'Dist': 1171,
#   'BA': 4,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 613,
#   'Price': 1,
#   'Name': 'Frenchmen House "Rose Room"',
#   'Polarity': 4132},
#  {'MinNights': 2,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 158,
#   '#Guests': 3,
#   'Listing Count': 3,
#   'Security': 8,
#   'CleanFee': 51,
#   'Dist': 504,
#   'BA': 5,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 175,
#   'Price': 2,
#   'Name': 'Luxury 2 Bed, 2.5 Bath - near French Quarter',
#   'Polarity': 3431},
#  {'MinNights': 2,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 226,
#   '#Guests': 3,
#   'Listing Count': 3,
#   'Security': 8,
#   'CleanFee': 85,
#   'Dist': 463,
#   'BA': 5,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 262,
#   'Price': 2,
#   'Name': 'Muse Suite- Near French Quarter',
#   'Polarity': 4355},
#  {'MinNights': 0,
#   'Hood': 9,
#   'SqFt': 20,
#   '#Reviews': 129,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 34,
#   'Dist': 3598,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 175,
#   'Price': 1,
#   'Name': 'Private SUITE in Perfect Neighborhood; BIKES incld',
#   'Polarity': 4868},
#  {'MinNights': 1,
#   'Hood': 4,
#   'SqFt': 20,
#   '#Reviews': 72,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 55,
#   'Dist': 5738,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 2,
#   '#Booked': 80,
#   'Price': 1,
#   'Name': 'The Pearl at Riverbend',
#   'Polarity': 5427},
#  {'MinNights': 1,
#   'Hood': 9,
#   'SqFt': 28,
#   '#Reviews': 166,
#   '#Guests': 5,
#   'Listing Count': 1,
#   'Security': 15,
#   'CleanFee': 69,
#   'Dist': 4006,
#   'BA': 1,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 185,
#   'Price': 2,
#   'Name': 'Quintessentially New Orleans',
#   'Polarity': 5337},
#  {'MinNights': 1,
#   'Hood': 37,
#   'SqFt': 22,
#   '#Reviews': 47,
#   '#Guests': 5,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 120,
#   'Dist': 1099,
#   'BA': 6,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 7,
#   '#Booked': 107,
#   'Price': 3,
#   'Name': 'La Boheme de Marigny - Historic Creole Cottage',
#   'Polarity': 3129},
#  {'MinNights': 2,
#   'Hood': 55,
#   'SqFt': 20,
#   '#Reviews': 285,
#   '#Guests': 1,
#   'Listing Count': 3,
#   'Security': 21,
#   'CleanFee': 30,
#   'Dist': 1973,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 469,
#   'Price': 1,
#   'Name': 'Maison Marais 2: Large Local Living',
#   'Polarity': 5236},
#  {'MinNights': 1,
#   'Hood': 15,
#   'SqFt': 20,
#   '#Reviews': 131,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 2,
#   'CleanFee': 21,
#   'Dist': 3227,
#   'BA': 3,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 4,
#   '#Booked': 148,
#   'Price': 0,
#   'Name': 'NOLA JAZZ FEST GETAWAY',
#   'Polarity': 4904},
#  {'MinNights': 2,
#   'Hood': 6,
#   'SqFt': 20,
#   '#Reviews': 225,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 16,
#   'Dist': 2230,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 5,
#   'Acc': 6,
#   '#Booked': 271,
#   'Price': 2,
#   'Name': 'Bywater Bungalow - Bikes & 4 Beds!',
#   'Polarity': 4555},
#  {'MinNights': 1,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 65,
#   '#Guests': 1,
#   'Listing Count': 5,
#   'Security': 28,
#   'CleanFee': 48,
#   'Dist': 1765,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 75,
#   'Price': 1,
#   'Name': 'Authentic New Orleans Home',
#   'Polarity': 2778},
#  {'MinNights': 1,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 4,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 15,
#   'CleanFee': 0,
#   'Dist': 1987,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 3,
#   '#Booked': 98,
#   'Price': 0,
#   'Name': 'Exquisite Treme Lafitte Shotgun Single Family',
#   'Polarity': 185},
#  {'MinNights': 2,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 158,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 48,
#   'Dist': 1395,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 7,
#   'Acc': 6,
#   '#Booked': 182,
#   'Price': 2,
#   'Name': 'Juke Joint Guest House -- Walk to French Quarter',
#   'Polarity': 4587},
#  {'MinNights': 1,
#   'Hood': 27,
#   'SqFt': 20,
#   '#Reviews': 134,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 8,
#   'CleanFee': 16,
#   'Dist': 4634,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 154,
#   'Price': 1,
#   'Name': 'Historic Irish Channel Corner Grocery',
#   'Polarity': 4913},
#  {'MinNights': 2,
#   'Hood': 14,
#   'SqFt': 26,
#   '#Reviews': 140,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 54,
#   'CleanFee': 68,
#   'Dist': 5119,
#   'BA': 6,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 180,
#   'Price': 3,
#   'Name': 'Indulge in the Heart of New Orleans',
#   'Polarity': 5225},
#  {'MinNights': 10,
#   'Hood': 2,
#   'SqFt': 20,
#   '#Reviews': 32,
#   '#Guests': 2,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 55,
#   'Dist': 3056,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 3,
#   '#Booked': 38,
#   'Price': 0,
#   'Name': 'Jazz Fest/ Bayou St John/ MardiGras',
#   'Polarity': 4789},
#  {'MinNights': 3,
#   'Hood': 27,
#   'SqFt': 20,
#   '#Reviews': 13,
#   '#Guests': 5,
#   'Listing Count': 1,
#   'Security': 57,
#   'CleanFee': 103,
#   'Dist': 4508,
#   'BA': 5,
#   'BR': 3,
#   'Beds': 5,
#   'Acc': 6,
#   '#Booked': 22,
#   'Price': 3,
#   'Name': 'Magazine St contemporary townhome (18STR-14210)',
#   'Polarity': 3620},
#  {'MinNights': 10,
#   'Hood': 6,
#   'SqFt': 20,
#   '#Reviews': 59,
#   '#Guests': 1,
#   'Listing Count': 11,
#   'Security': 33,
#   'CleanFee': 81,
#   'Dist': 2770,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 69,
#   'Price': 2,
#   'Name': 'Bywater Hideout-Bikes-Remodeled-Monthly-Festivals!',
#   'Polarity': 5214},
#  {'MinNights': 2,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 59,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 15,
#   'CleanFee': 34,
#   'Dist': 1003,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 69,
#   'Price': 2,
#   'Name': 'Historic pied-à-terre on Esplanade',
#   'Polarity': 3546},
#  {'MinNights': 10,
#   'Hood': 68,
#   'SqFt': 20,
#   '#Reviews': 8,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 52,
#   'CleanFee': 85,
#   'Dist': 2576,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 6,
#   '#Booked': 10,
#   'Price': 0,
#   'Name': 'Algiers Point, New Orleans LA - Funky NOLA Digs',
#   'Polarity': 3127},
#  {'MinNights': 1,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 157,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 2,
#   'CleanFee': 69,
#   'Dist': 1032,
#   'BA': 4,
#   'BR': 2,
#   'Beds': 6,
#   'Acc': 6,
#   '#Booked': 184,
#   'Price': 2,
#   'Name': 'The Burgundy Cottage - Marigny Triangle',
#   'Polarity': 5191},
#  {'MinNights': 1,
#   'Hood': 0,
#   'SqFt': 12,
#   '#Reviews': 90,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 52,
#   'CleanFee': 30,
#   'Dist': 1985,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 3,
#   '#Booked': 262,
#   'Price': 1,
#   'Name': "Stunning 1800's double-shotgun in New Orleans.",
#   'Polarity': 3375},
#  {'MinNights': 3,
#   'Hood': 6,
#   'SqFt': 20,
#   '#Reviews': 275,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 15,
#   'CleanFee': 27,
#   'Dist': 2471,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 3,
#   '#Booked': 415,
#   'Price': 1,
#   'Name': 'Stylish Home Walking Distance to French Quarter Free Bikes',
#   'Polarity': 5076},
#  {'MinNights': 3,
#   'Hood': 38,
#   'SqFt': 20,
#   '#Reviews': 37,
#   '#Guests': 5,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 69,
#   'Dist': 4314,
#   'BA': 4,
#   'BR': 3,
#   'Beds': 5,
#   'Acc': 6,
#   '#Booked': 44,
#   'Price': 3,
#   'Name': '3 Bedrm/2 Bath - Bike to Jazz Fest!',
#   'Polarity': 3251},
#  {'MinNights': 3,
#   'Hood': 9,
#   'SqFt': 29,
#   '#Reviews': 31,
#   '#Guests': 1,
#   'Listing Count': 4,
#   'Security': 18,
#   'CleanFee': 69,
#   'Dist': 4094,
#   'BA': 3,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 37,
#   'Price': 2,
#   'Name': 'City Park Private Room/ Bath',
#   'Polarity': 5747},
#  {'MinNights': 2,
#   'Hood': 14,
#   'SqFt': 20,
#   '#Reviews': 117,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 40,
#   'Dist': 4837,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 2,
#   '#Booked': 139,
#   'Price': 1,
#   'Name': 'Charming Shotgun Cottage Uptown',
#   'Polarity': 5010},
#  {'MinNights': 2,
#   'Hood': 37,
#   'SqFt': 6,
#   '#Reviews': 257,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 2,
#   'CleanFee': 34,
#   'Dist': 904,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 345,
#   'Price': 2,
#   'Name': 'Little Gem',
#   'Polarity': 4794},
#  {'MinNights': 1,
#   'Hood': 15,
#   'SqFt': 25,
#   '#Reviews': 51,
#   '#Guests': 1,
#   'Listing Count': 4,
#   'Security': 18,
#   'CleanFee': 69,
#   'Dist': 3291,
#   'BA': 4,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 61,
#   'Price': 3,
#   'Name': 'City Park Purple Orchid Upstairs',
#   'Polarity': 2783},
#  {'MinNights': 2,
#   'Hood': 8,
#   'SqFt': 20,
#   '#Reviews': 17,
#   '#Guests': 0,
#   'Listing Count': 4,
#   'Security': 18,
#   'CleanFee': 30,
#   'Dist': 3958,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 21,
#   'Price': 1,
#   'Name': 'Modern and Fun - Centrally Located',
#   'Polarity': 4871},
#  {'MinNights': 1,
#   'Hood': 15,
#   'SqFt': 20,
#   '#Reviews': 36,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 2,
#   'CleanFee': 21,
#   'Dist': 3449,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 2,
#   '#Booked': 45,
#   'Price': 0,
#   'Name': 'New Orleans Jazz Fest Getaway 2',
#   'Polarity': 5082},
#  {'MinNights': 2,
#   'Hood': 27,
#   'SqFt': 20,
#   '#Reviews': 61,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 38,
#   'CleanFee': 48,
#   'Dist': 4771,
#   'BA': 4,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 5,
#   '#Booked': 74,
#   'Price': 2,
#   'Name': 'Garden District "IRISH CHANNEL" Home 2bd/2bath',
#   'Polarity': 1677},
#  {'MinNights': 0,
#   'Hood': 59,
#   'SqFt': 24,
#   '#Reviews': 51,
#   '#Guests': 5,
#   'Listing Count': 19,
#   'Security': 28,
#   'CleanFee': 113,
#   'Dist': 682,
#   'BA': 6,
#   'BR': 3,
#   'Beds': 7,
#   'Acc': 6,
#   '#Booked': 105,
#   'Price': 3,
#   'Name': 'Tremé Creole Cottage (A)',
#   'Polarity': 2587},
#  {'MinNights': 2,
#   'Hood': 56,
#   'SqFt': 20,
#   '#Reviews': 154,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 26,
#   'CleanFee': 54,
#   'Dist': 4182,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 5,
#   'Acc': 6,
#   '#Booked': 187,
#   'Price': 2,
#   'Name': 'Near bustling Magazine St w/BIKES!',
#   'Polarity': 4821},
#  {'MinNights': 2,
#   'Hood': 16,
#   'SqFt': 20,
#   '#Reviews': 59,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 18,
#   'CleanFee': 34,
#   'Dist': 5358,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 71,
#   'Price': 0,
#   'Name': 'Pondokku di New Orleans lic#17STR (Phone number hidden by Airbnb)',
#   'Polarity': 2782},
#  {'MinNights': 1,
#   'Hood': 67,
#   'SqFt': 20,
#   '#Reviews': 63,
#   '#Guests': 3,
#   'Listing Count': 5,
#   'Security': 0,
#   'CleanFee': 69,
#   'Dist': 5784,
#   'BA': 4,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 76,
#   'Price': 2,
#   'Name': 'Stumble to all things New Orleans',
#   'Polarity': 2729},
#  {'MinNights': 1,
#   'Hood': 2,
#   'SqFt': 20,
#   '#Reviews': 26,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 38,
#   'CleanFee': 69,
#   'Dist': 3140,
#   'BA': 1,
#   'BR': 0,
#   'Beds': 5,
#   'Acc': 7,
#   '#Booked': 43,
#   'Price': 2,
#   'Name': 'Bayou St. John Cottage!!',
#   'Polarity': 5296},
#  {'MinNights': 1,
#   'Hood': 15,
#   'SqFt': 20,
#   '#Reviews': 127,
#   '#Guests': 5,
#   'Listing Count': 1,
#   'Security': 28,
#   'CleanFee': 103,
#   'Dist': 2864,
#   'BA': 4,
#   'BR': 6,
#   'Beds': 11,
#   'Acc': 16,
#   '#Booked': 171,
#   'Price': 4,
#   'Name': '3 Blocks to Jazz Fest! Big Beautiful Best!Sleep 16',
#   'Polarity': 4848},
#  {'MinNights': 8,
#   'Hood': 54,
#   'SqFt': 18,
#   '#Reviews': 158,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 56,
#   'CleanFee': 0,
#   'Dist': 3939,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 190,
#   'Price': 0,
#   'Name': 'Bywater Curio Space: artful living',
#   'Polarity': 4985},
#  {'MinNights': 0,
#   'Hood': 1,
#   'SqFt': 20,
#   '#Reviews': 21,
#   '#Guests': 9,
#   'Listing Count': 2,
#   'Security': 15,
#   'CleanFee': 120,
#   'Dist': 5251,
#   'BA': 6,
#   'BR': 4,
#   'Beds': 11,
#   'Acc': 14,
#   '#Booked': 26,
#   'Price': 4,
#   'Name': 'Uptown Jewel',
#   'Polarity': 2200},
#  {'MinNights': 2,
#   'Hood': 6,
#   'SqFt': 12,
#   '#Reviews': 270,
#   '#Guests': 1,
#   'Listing Count': 7,
#   'Security': 2,
#   'CleanFee': 16,
#   'Dist': 1814,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 2,
#   '#Booked': 432,
#   'Price': 1,
#   'Name': 'Private oasis in the Marigny',
#   'Polarity': 4938},
#  {'MinNights': 0,
#   'Hood': 8,
#   'SqFt': 2,
#   '#Reviews': 244,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 55,
#   'Dist': 2057,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 461,
#   'Price': 1,
#   'Name': 'Artistic Mansion',
#   'Polarity': 2078},
#  {'MinNights': 1,
#   'Hood': 62,
#   'SqFt': 20,
#   '#Reviews': 107,
#   '#Guests': 1,
#   'Listing Count': 5,
#   'Security': 0,
#   'CleanFee': 69,
#   'Dist': 5265,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 131,
#   'Price': 1,
#   'Name': 'Uptown - Revelry, Dining, and Music',
#   'Polarity': 3972},
#  {'MinNights': 0,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 12,
#   '#Guests': 3,
#   'Listing Count': 2,
#   'Security': 38,
#   'CleanFee': 88,
#   'Dist': 941,
#   'BA': 5,
#   'BR': 3,
#   'Beds': 5,
#   'Acc': 6,
#   '#Booked': 15,
#   'Price': 3,
#   'Name': 'Spacious, Historic Treme Home with Vintage Charm',
#   'Polarity': 3999},
#  {'MinNights': 1,
#   'Hood': 40,
#   'SqFt': 20,
#   '#Reviews': 67,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 18,
#   'CleanFee': 55,
#   'Dist': 3804,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 87,
#   'Price': 3,
#   'Name': 'Mid City Apartment with Pool Access',
#   'Polarity': 1943},
#  {'MinNights': 1,
#   'Hood': 51,
#   'SqFt': 20,
#   '#Reviews': 295,
#   '#Guests': 1,
#   'Listing Count': 4,
#   'Security': 0,
#   'CleanFee': 21,
#   'Dist': 1317,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 2,
#   '#Booked': 569,
#   'Price': 1,
#   'Name': 'Creole Cottage in Historic Treme Upstairs Suite',
#   'Polarity': 4441},
#  {'MinNights': 2,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 45,
#   '#Guests': 5,
#   'Listing Count': 1,
#   'Security': 49,
#   'CleanFee': 126,
#   'Dist': 1028,
#   'BA': 4,
#   'BR': 3,
#   'Beds': 7,
#   'Acc': 6,
#   '#Booked': 58,
#   'Price': 3,
#   'Name': 'Awesome home at Frenchmen St.! Walk to Bourbon!!',
#   'Polarity': 5384},
#  {'MinNights': 1,
#   'Hood': 5,
#   'SqFt': 20,
#   '#Reviews': 104,
#   '#Guests': 2,
#   'Listing Count': 10,
#   'Security': 26,
#   'CleanFee': 0,
#   'Dist': 3681,
#   'BA': 1,
#   'BR': 3,
#   'Beds': 6,
#   'Acc': 10,
#   '#Booked': 132,
#   'Price': 2,
#   'Name': '"The Monte Cristo"',
#   'Polarity': 3496},
#  {'MinNights': 1,
#   'Hood': 51,
#   'SqFt': 20,
#   '#Reviews': 297,
#   '#Guests': 1,
#   'Listing Count': 4,
#   'Security': 0,
#   'CleanFee': 16,
#   'Dist': 1591,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 586,
#   'Price': 0,
#   'Name': 'Creole Cottage in historic Treme Master Bedroom',
#   'Polarity': 4784},
#  {'MinNights': 0,
#   'Hood': 40,
#   'SqFt': 20,
#   '#Reviews': 24,
#   '#Guests': 5,
#   'Listing Count': 7,
#   'Security': 21,
#   'CleanFee': 55,
#   'Dist': 3757,
#   'BA': 4,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 32,
#   'Price': 3,
#   'Name': 'Half of The Okra Inn: On Canal Streetcar Line',
#   'Polarity': 5310},
#  {'MinNights': 1,
#   'Hood': 54,
#   'SqFt': 20,
#   '#Reviews': 263,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 15,
#   'CleanFee': 55,
#   'Dist': 2772,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 379,
#   'Price': 1,
#   'Name': 'Bywater Victorian Double 17STR-09907',
#   'Polarity': 5170},
#  {'MinNights': 3,
#   'Hood': 9,
#   'SqFt': 20,
#   '#Reviews': 58,
#   '#Guests': 0,
#   'Listing Count': 4,
#   'Security': 0,
#   'CleanFee': 69,
#   'Dist': 4394,
#   'BA': 3,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 73,
#   'Price': 2,
#   'Name': 'City Park Rest Haven, Front Unit',
#   'Polarity': 4762},
#  {'MinNights': 1,
#   'Hood': 51,
#   'SqFt': 20,
#   '#Reviews': 290,
#   '#Guests': 0,
#   'Listing Count': 4,
#   'Security': 0,
#   'CleanFee': 9,
#   'Dist': 1557,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 553,
#   'Price': 0,
#   'Name': 'Creole Cottage in historic Treme Room #3',
#   'Polarity': 4596},
#  {'MinNights': 1,
#   'Hood': 8,
#   'SqFt': 20,
#   '#Reviews': 86,
#   '#Guests': 0,
#   'Listing Count': 5,
#   'Security': 18,
#   'CleanFee': 69,
#   'Dist': 3730,
#   'BA': 3,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 111,
#   'Price': 2,
#   'Name': 'Lovely Landmark, Central Location: 17STR-10292',
#   'Polarity': 3584},
#  {'MinNights': 1,
#   'Hood': 62,
#   'SqFt': 20,
#   '#Reviews': 99,
#   '#Guests': 1,
#   'Listing Count': 5,
#   'Security': 0,
#   'CleanFee': 69,
#   'Dist': 5328,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 125,
#   'Price': 1,
#   'Name': 'Music, Food, & Fun at your Doorstep',
#   'Polarity': 3751},
#  {'MinNights': 2,
#   'Hood': 35,
#   'SqFt': 20,
#   '#Reviews': 68,
#   '#Guests': 5,
#   'Listing Count': 2,
#   'Security': 38,
#   'CleanFee': 103,
#   'Dist': 3118,
#   'BA': 5,
#   'BR': 3,
#   'Beds': 0,
#   'Acc': 6,
#   '#Booked': 92,
#   'Price': 3,
#   'Name': 'Luxury Home, Excellent Location',
#   'Polarity': 5096},
#  {'MinNights': 2,
#   'Hood': 54,
#   'SqFt': 20,
#   '#Reviews': 35,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 33,
#   'CleanFee': 34,
#   'Dist': 2866,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 45,
#   'Price': 2,
#   'Name': 'Bohemian Bywater Cottage',
#   'Polarity': 5709},
#  {'MinNights': 1,
#   'Hood': 14,
#   'SqFt': 20,
#   '#Reviews': 128,
#   '#Guests': 5,
#   'Listing Count': 2,
#   'Security': 2,
#   'CleanFee': 69,
#   'Dist': 4910,
#   'BA': 4,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 163,
#   'Price': 3,
#   'Name': '3BR Uptown New Orleans Style House',
#   'Polarity': 1775},
#  {'MinNights': 2,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 115,
#   '#Guests': 6,
#   'Listing Count': 2,
#   'Security': 40,
#   'CleanFee': 64,
#   'Dist': 1246,
#   'BA': 6,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 151,
#   'Price': 3,
#   'Name': 'Elegantly Decayed  Creole Mansion ( (Phone number hidden by Airbnb)',
#   'Polarity': 3639},
#  {'MinNights': 2,
#   'Hood': 15,
#   'SqFt': 20,
#   '#Reviews': 101,
#   '#Guests': 0,
#   'Listing Count': 4,
#   'Security': 18,
#   'CleanFee': 69,
#   'Dist': 3472,
#   'BA': 4,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 131,
#   'Price': 2,
#   'Name': 'City Park Purple Orchid, Downstairs',
#   'Polarity': 2995},
#  {'MinNights': 0,
#   'Hood': 54,
#   'SqFt': 20,
#   '#Reviews': 144,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 2,
#   'CleanFee': 27,
#   'Dist': 2933,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 285,
#   'Price': 0,
#   'Name': 'Stay in a Magical Art House',
#   'Polarity': 4523},
#  {'MinNights': 1,
#   'Hood': 33,
#   'SqFt': 20,
#   '#Reviews': 61,
#   '#Guests': 3,
#   'Listing Count': 5,
#   'Security': 18,
#   'CleanFee': 69,
#   'Dist': 5012,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 79,
#   'Price': 2,
#   'Name': '2/1 - Comfortable. Great Location Lic: 17STR-10295',
#   'Polarity': 3891},
#  {'MinNights': 1,
#   'Hood': 33,
#   'SqFt': 20,
#   '#Reviews': 37,
#   '#Guests': 3,
#   'Listing Count': 5,
#   'Security': 18,
#   'CleanFee': 69,
#   'Dist': 5049,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 48,
#   'Price': 2,
#   'Name': '2/1 - Lovely + spacious + location, #: 17STR-10294',
#   'Polarity': 4259},
#  {'MinNights': 2,
#   'Hood': 9,
#   'SqFt': 20,
#   '#Reviews': 98,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 34,
#   'Dist': 3969,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 126,
#   'Price': 1,
#   'Name': 'Beautiful Efficiency Apartment',
#   'Polarity': 5456},
#  {'MinNights': 1,
#   'Hood': 7,
#   'SqFt': 27,
#   '#Reviews': 11,
#   '#Guests': 3,
#   'Listing Count': 2,
#   'Security': 38,
#   'CleanFee': 94,
#   'Dist': 445,
#   'BA': 4,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 6,
#   '#Booked': 14,
#   'Price': 3,
#   'Name': 'Upscale Luxury Penthouse (2/2)-Walk Everywhere!',
#   'Polarity': 1661},
#  {'MinNights': 1,
#   'Hood': 55,
#   'SqFt': 20,
#   '#Reviews': 163,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 0,
#   'CleanFee': 5,
#   'Dist': 2811,
#   'BA': 2,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 209,
#   'Price': 0,
#   'Name': 'Quiet Stroll to the Quarter #1',
#   'Polarity': 3996},
#  {'MinNights': 1,
#   'Hood': 55,
#   'SqFt': 20,
#   '#Reviews': 205,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 0,
#   'CleanFee': 5,
#   'Dist': 2685,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 264,
#   'Price': 0,
#   'Name': 'Quiet Stroll to the Quarter #2',
#   'Polarity': 2800},
#  {'MinNights': 0,
#   'Hood': 40,
#   'SqFt': 20,
#   '#Reviews': 298,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 9,
#   'Dist': 3245,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 622,
#   'Price': 1,
#   'Name': 'Ride the Streetcar to the French Quarter!',
#   'Polarity': 4041},
#  {'MinNights': 1,
#   'Hood': 15,
#   'SqFt': 20,
#   '#Reviews': 131,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 34,
#   'Dist': 2907,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 169,
#   'Price': 0,
#   'Name': 'Private wing of house with pool',
#   'Polarity': 5240},
#  {'MinNights': 2,
#   'Hood': 54,
#   'SqFt': 20,
#   '#Reviews': 194,
#   '#Guests': 1,
#   'Listing Count': 4,
#   'Security': 15,
#   'CleanFee': 27,
#   'Dist': 2316,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 254,
#   'Price': 1,
#   'Name': 'Sky Loft Bywater-Marigny-Great LOCATION',
#   'Polarity': 4408},
#  {'MinNights': 0,
#   'Hood': 40,
#   'SqFt': 20,
#   '#Reviews': 160,
#   '#Guests': 1,
#   'Listing Count': 7,
#   'Security': 8,
#   'CleanFee': 55,
#   'Dist': 3885,
#   'BA': 4,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 206,
#   'Price': 0,
#   'Name': 'The Okra Inn Master: On Canal Streetcar Line',
#   'Polarity': 2716},
#  {'MinNights': 0,
#   'Hood': 40,
#   'SqFt': 20,
#   '#Reviews': 147,
#   '#Guests': 1,
#   'Listing Count': 7,
#   'Security': 8,
#   'CleanFee': 55,
#   'Dist': 3905,
#   'BA': 4,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 189,
#   'Price': 1,
#   'Name': "The Okra Inn's Balcony Room: On Canal Streetcar",
#   'Polarity': 4621},
#  {'MinNights': 1,
#   'Hood': 16,
#   'SqFt': 20,
#   '#Reviews': 233,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 18,
#   'CleanFee': 48,
#   'Dist': 5361,
#   'BA': 1,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 341,
#   'Price': 0,
#   'Name': 'Rumahku De New Orleans lic#17STR (Phone number hidden by Airbnb)',
#   'Polarity': 3164},
#  {'MinNights': 1,
#   'Hood': 15,
#   'SqFt': 20,
#   '#Reviews': 143,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 45,
#   'Dist': 3478,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 4,
#   '#Booked': 184,
#   'Price': 1,
#   'Name': 'STEPS TO JAZZ FEST!',
#   'Polarity': 4810},
#  {'MinNights': 2,
#   'Hood': 16,
#   'SqFt': 20,
#   '#Reviews': 6,
#   '#Guests': 3,
#   'Listing Count': 4,
#   'Security': 28,
#   'CleanFee': 120,
#   'Dist': 5536,
#   'BA': 5,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 8,
#   'Price': 2,
#   'Name': 'JAZZFEST SPECIAL!!!! COURTYARD',
#   'Polarity': 4014},
#  {'MinNights': 1,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 176,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 18,
#   'CleanFee': 21,
#   'Dist': 1287,
#   'BA': 3,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 236,
#   'Price': 2,
#   'Name': 'Huckabuck Village in Historic Treme',
#   'Polarity': 5600},
#  {'MinNights': 2,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 143,
#   '#Guests': 5,
#   'Listing Count': 1,
#   'Security': 8,
#   'CleanFee': 48,
#   'Dist': 1279,
#   'BA': 4,
#   'BR': 3,
#   'Beds': 5,
#   'Acc': 6,
#   '#Booked': 194,
#   'Price': 2,
#   'Name': 'Cabaret life! Three bedrooms w/ wraparound balcony',
#   'Polarity': 2154},
#  {'MinNights': 1,
#   'Hood': 6,
#   'SqFt': 16,
#   '#Reviews': 282,
#   '#Guests': 3,
#   'Listing Count': 2,
#   'Security': 18,
#   'CleanFee': 27,
#   'Dist': 3679,
#   'BA': 1,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 503,
#   'Price': 1,
#   'Name': 'NEAR THE RIVER IN THE SAFE AND HISTORIC BYWATER!',
#   'Polarity': 4712},
#  {'MinNights': 1,
#   'Hood': 35,
#   'SqFt': 20,
#   '#Reviews': 29,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 2,
#   'CleanFee': 13,
#   'Dist': 3393,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 41,
#   'Price': 0,
#   'Name': 'Cozy space for yogis and dog-lovers',
#   'Polarity': 4501},
#  {'MinNights': 1,
#   'Hood': 5,
#   'SqFt': 20,
#   '#Reviews': 177,
#   '#Guests': 1,
#   'Listing Count': 10,
#   'Security': 2,
#   'CleanFee': 5,
#   'Dist': 3662,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 233,
#   'Price': 0,
#   'Name': 'Beignet Place',
#   'Polarity': 1505},
#  {'MinNights': 1,
#   'Hood': 5,
#   'SqFt': 20,
#   '#Reviews': 126,
#   '#Guests': 3,
#   'Listing Count': 10,
#   'Security': 26,
#   'CleanFee': 0,
#   'Dist': 3694,
#   'BA': 3,
#   'BR': 3,
#   'Beds': 5,
#   'Acc': 10,
#   '#Booked': 171,
#   'Price': 2,
#   'Name': 'Cristo Loft',
#   'Polarity': 2341},
#  {'MinNights': 1,
#   'Hood': 2,
#   'SqFt': 29,
#   '#Reviews': 58,
#   '#Guests': 5,
#   'Listing Count': 1,
#   'Security': 15,
#   'CleanFee': 88,
#   'Dist': 2558,
#   'BA': 4,
#   'BR': 3,
#   'Beds': 6,
#   'Acc': 6,
#   '#Booked': 80,
#   'Price': 3,
#   'Name': 'Large Apt Bayou St John/City Park',
#   'Polarity': 4707},
#  {'MinNights': 2,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 68,
#   '#Guests': 9,
#   'Listing Count': 1,
#   'Security': 52,
#   'CleanFee': 120,
#   'Dist': 1993,
#   'BA': 7,
#   'BR': 5,
#   'Beds': 7,
#   'Acc': 10,
#   '#Booked': 92,
#   'Price': 4,
#   'Name': 'Majestic 5 bedroom mansion close to the FQ',
#   'Polarity': 2165},
#  {'MinNights': 2,
#   'Hood': 25,
#   'SqFt': 20,
#   '#Reviews': 73,
#   '#Guests': 1,
#   'Listing Count': 5,
#   'Security': 26,
#   'CleanFee': 48,
#   'Dist': 4399,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 99,
#   'Price': 1,
#   'Name': 'GUEST WING BY THE RIVER ~2 Q Bedrooms',
#   'Polarity': 4909},
#  {'MinNights': 1,
#   'Hood': 8,
#   'SqFt': 20,
#   '#Reviews': 34,
#   '#Guests': 1,
#   'Listing Count': 5,
#   'Security': 0,
#   'CleanFee': 69,
#   'Dist': 3648,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 78,
#   'Price': 2,
#   'Name': 'City Cove:   License  #: 17STR-10293',
#   'Polarity': 921},
#  {'MinNights': 2,
#   'Hood': 8,
#   'SqFt': 20,
#   '#Reviews': 22,
#   '#Guests': 1,
#   'Listing Count': 8,
#   'Security': 26,
#   'CleanFee': 88,
#   'Dist': 3539,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 30,
#   'Price': 2,
#   'Name': 'Garden District, DT Views, Comfort',
#   'Polarity': 4940},
#  {'MinNights': 2,
#   'Hood': 8,
#   'SqFt': 20,
#   '#Reviews': 50,
#   '#Guests': 1,
#   'Listing Count': 8,
#   'Security': 38,
#   'CleanFee': 85,
#   'Dist': 3407,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 67,
#   'Price': 3,
#   'Name': 'Mardi Gras Balcony Views in Historic Garden District',
#   'Polarity': 5277},
#  {'MinNights': 2,
#   'Hood': 8,
#   'SqFt': 20,
#   '#Reviews': 16,
#   '#Guests': 0,
#   'Listing Count': 8,
#   'Security': 15,
#   'CleanFee': 48,
#   'Dist': 3308,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 22,
#   'Price': 2,
#   'Name': 'Walk to St Charles, private deck',
#   'Polarity': 5275},
#  {'MinNights': 1,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 125,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 18,
#   'CleanFee': 21,
#   'Dist': 1077,
#   'BA': 3,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 167,
#   'Price': 1,
#   'Name': 'King rm @ Huckabuck Village, Treme ',
#   'Polarity': 5693},
#  {'MinNights': 1,
#   'Hood': 67,
#   'SqFt': 20,
#   '#Reviews': 43,
#   '#Guests': 1,
#   'Listing Count': 5,
#   'Security': 0,
#   'CleanFee': 69,
#   'Dist': 5817,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 67,
#   'Price': 1,
#   'Name': 'Wine, Dine, & Relax in Uptown NOLA',
#   'Polarity': 1869},
#  {'MinNights': 3,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 146,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 52,
#   'CleanFee': 103,
#   'Dist': 1073,
#   'BA': 5,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 197,
#   'Price': 3,
#   'Name': 'Fab Frenchmen Maison on the Park',
#   'Polarity': 4939},
#  {'MinNights': 1,
#   'Hood': 33,
#   'SqFt': 22,
#   '#Reviews': 84,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 38,
#   'CleanFee': 42,
#   'Dist': 5169,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 114,
#   'Price': 2,
#   'Name': 'Fab Apt with Perfect Park Porch',
#   'Polarity': 5235},
#  {'MinNights': 1,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 123,
#   '#Guests': 2,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 28,
#   'Dist': 1035,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 166,
#   'Price': 2,
#   'Name': 'Historic Marigny Triangle Apartment',
#   'Polarity': 3705},
#  {'MinNights': 1,
#   'Hood': 8,
#   'SqFt': 20,
#   '#Reviews': 178,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 2,
#   'CleanFee': 27,
#   'Dist': 3872,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 246,
#   'Price': 0,
#   'Name': 'Master Bedroom + Streetcar + Private Entry w/Bath',
#   'Polarity': 3872},
#  {'MinNights': 0,
#   'Hood': 15,
#   'SqFt': 20,
#   '#Reviews': 285,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 0,
#   'CleanFee': 5,
#   'Dist': 2589,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 554,
#   'Price': 0,
#   'Name': 'Free Bikes -The Luscious Red Room!',
#   'Polarity': 2061},
#  {'MinNights': 0,
#   'Hood': 15,
#   'SqFt': 20,
#   '#Reviews': 291,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 0,
#   'CleanFee': 5,
#   'Dist': 2621,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 590,
#   'Price': 0,
#   'Name': 'Le Peach Parlor,Free Bikes,Loft Bed',
#   'Polarity': 1491},
#  {'MinNights': 3,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 4,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 0,
#   'CleanFee': 0,
#   'Dist': 1673,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 6,
#   'Price': 1,
#   'Name': 'Maison Mandeville 2 in the Marigny',
#   'Polarity': 498},
#  {'MinNights': 1,
#   'Hood': 13,
#   'SqFt': 20,
#   '#Reviews': 72,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 8,
#   'CleanFee': 69,
#   'Dist': 5327,
#   'BA': 4,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 98,
#   'Price': 1,
#   'Name': 'NOLA house 3 blocks from streetcar',
#   'Polarity': 4943},
#  {'MinNights': 2,
#   'Hood': 51,
#   'SqFt': 20,
#   '#Reviews': 165,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 21,
#   'CleanFee': 23,
#   'Dist': 1862,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 223,
#   'Price': 1,
#   'Name': 'Cozy Master Suite Bungalow',
#   'Polarity': 4928},
#  {'MinNights': 3,
#   'Hood': 27,
#   'SqFt': 20,
#   '#Reviews': 38,
#   '#Guests': 0,
#   'Listing Count': 3,
#   'Security': 18,
#   'CleanFee': 141,
#   'Dist': 4622,
#   'BA': 6,
#   'BR': 4,
#   'Beds': 5,
#   'Acc': 8,
#   '#Booked': 72,
#   'Price': 4,
#   'Name': 'Privacy and Luxury',
#   'Polarity': 2831},
#  {'MinNights': 2,
#   'Hood': 9,
#   'SqFt': 20,
#   '#Reviews': 52,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 28,
#   'CleanFee': 30,
#   'Dist': 4042,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 71,
#   'Price': 1,
#   'Name': 'City Park, Mid City, Safe area near Streetcar Stop',
#   'Polarity': 4244},
#  {'MinNights': 1,
#   'Hood': 0,
#   'SqFt': 22,
#   '#Reviews': 11,
#   '#Guests': 1,
#   'Listing Count': 4,
#   'Security': 2,
#   'CleanFee': 0,
#   'Dist': 1704,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 15,
#   'Price': 3,
#   'Name': 'QUIET N SAFE FERRY TO QUARTER',
#   'Polarity': 902},
#  {'MinNights': 3,
#   'Hood': 8,
#   'SqFt': 20,
#   '#Reviews': 58,
#   '#Guests': 7,
#   'Listing Count': 8,
#   'Security': 52,
#   'CleanFee': 141,
#   'Dist': 3321,
#   'BA': 8,
#   'BR': 5,
#   'Beds': 9,
#   'Acc': 10,
#   '#Booked': 79,
#   'Price': 4,
#   'Name': 'Mansion in the Garden District',
#   'Polarity': 4511},
#  {'MinNights': 1,
#   'Hood': 35,
#   'SqFt': 17,
#   '#Reviews': 69,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 50,
#   'Dist': 2612,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 94,
#   'Price': 2,
#   'Name': 'Lower Garden Condo (Under 1 mile to Conv Center)',
#   'Polarity': 2330},
#  {'MinNights': 3,
#   'Hood': 2,
#   'SqFt': 20,
#   '#Reviews': 109,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 0,
#   'CleanFee': 40,
#   'Dist': 2683,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 148,
#   'Price': 1,
#   'Name': 'Under the Oaks on Ursulines',
#   'Polarity': 5042},
#  {'MinNights': 1,
#   'Hood': 40,
#   'SqFt': 20,
#   '#Reviews': 162,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 38,
#   'CleanFee': 69,
#   'Dist': 3348,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 219,
#   'Price': 2,
#   'Name': 'New Orleans Spacious Apt. Sleeps 6 On Canal Street',
#   'Polarity': 5243},
#  {'MinNights': 2,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 122,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 21,
#   'CleanFee': 34,
#   'Dist': 2078,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 5,
#   '#Booked': 165,
#   'Price': 2,
#   'Name': 'Historic Apt in Magical Marigny',
#   'Polarity': 5565},
#  {'MinNights': 1,
#   'Hood': 54,
#   'SqFt': 20,
#   '#Reviews': 114,
#   '#Guests': 2,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 55,
#   'Dist': 2425,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 154,
#   'Price': 1,
#   'Name': 'private getaway near french quarter',
#   'Polarity': 1286},
#  {'MinNights': 2,
#   'Hood': 56,
#   'SqFt': 20,
#   '#Reviews': 126,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 0,
#   'CleanFee': 13,
#   'Dist': 3723,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 171,
#   'Price': 1,
#   'Name': 'Lovely Private Rm near Magazine St',
#   'Polarity': 5031},
#  {'MinNights': 1,
#   'Hood': 16,
#   'SqFt': 20,
#   '#Reviews': 91,
#   '#Guests': 3,
#   'Listing Count': 5,
#   'Security': 15,
#   'CleanFee': 107,
#   'Dist': 5018,
#   'BA': 5,
#   'BR': 5,
#   'Beds': 10,
#   'Acc': 10,
#   '#Booked': 123,
#   'Price': 3,
#   'Name': 'Mandolin / 40%Off Spring  5BR/2.5BA/Festival!',
#   'Polarity': 3003},
#  {'MinNights': 1,
#   'Hood': 15,
#   'SqFt': 20,
#   '#Reviews': 76,
#   '#Guests': 1,
#   'Listing Count': 3,
#   'Security': 38,
#   'CleanFee': 23,
#   'Dist': 3163,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 107,
#   'Price': 1,
#   'Name': 'Luxurious King Suite',
#   'Polarity': 5624},
#  {'MinNights': 2,
#   'Hood': 9,
#   'SqFt': 13,
#   '#Reviews': 87,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 34,
#   'Dist': 3765,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 3,
#   '#Booked': 118,
#   'Price': 1,
#   'Name': 'Mid-City- Newly Renovated Efficiency!',
#   'Polarity': 4525},
#  {'MinNights': 0,
#   'Hood': 40,
#   'SqFt': 20,
#   '#Reviews': 67,
#   '#Guests': 5,
#   'Listing Count': 1,
#   'Security': 38,
#   'CleanFee': 48,
#   'Dist': 3746,
#   'BA': 3,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 92,
#   'Price': 3,
#   'Name': 'Mid-City Craftsman',
#   'Polarity': 4729},
#  {'MinNights': 0,
#   'Hood': 33,
#   'SqFt': 20,
#   '#Reviews': 67,
#   '#Guests': 3,
#   'Listing Count': 3,
#   'Security': 39,
#   'CleanFee': 42,
#   'Dist': 5461,
#   'BA': 1,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 5,
#   '#Booked': 99,
#   'Price': 1,
#   'Name': 'The Blue Heart',
#   'Polarity': 3367},
#  {'MinNights': 1,
#   'Hood': 15,
#   'SqFt': 20,
#   '#Reviews': 28,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 38,
#   'CleanFee': 45,
#   'Dist': 3194,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 38,
#   'Price': 2,
#   'Name': 'Bayou St. John Carriage House',
#   'Polarity': 5327},
#  {'MinNights': 2,
#   'Hood': 62,
#   'SqFt': 29,
#   '#Reviews': 23,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 60,
#   'CleanFee': 69,
#   'Dist': 5394,
#   'BA': 5,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 37,
#   'Price': 3,
#   'Name': 'Uptown Magazine St - New Open Condo',
#   'Polarity': 5716},
#  {'MinNights': 10,
#   'Hood': 15,
#   'SqFt': 20,
#   '#Reviews': 61,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 2,
#   'CleanFee': 40,
#   'Dist': 3418,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 84,
#   'Price': 0,
#   'Name': 'Retro Cottage near Bayou/ Jazz Fest',
#   'Polarity': 5289},
#  {'MinNights': 1,
#   'Hood': 58,
#   'SqFt': 20,
#   '#Reviews': 6,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 27,
#   'Dist': 4570,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 21,
#   'Price': 2,
#   'Name': 'Creole Guest Suite next to Garden District',
#   'Polarity': 5376},
#  {'MinNights': 1,
#   'Hood': 51,
#   'SqFt': 8,
#   '#Reviews': 255,
#   '#Guests': 3,
#   'Listing Count': 5,
#   'Security': 2,
#   'CleanFee': 85,
#   'Dist': 1045,
#   'BA': 1,
#   'BR': 3,
#   'Beds': 5,
#   'Acc': 6,
#   '#Booked': 413,
#   'Price': 2,
#   'Name': 'Marigny Oak House by French Quarter, Free Bikes',
#   'Polarity': 3949},
#  {'MinNights': 0,
#   'Hood': 1,
#   'SqFt': 20,
#   '#Reviews': 150,
#   '#Guests': 0,
#   'Listing Count': 3,
#   'Security': 2,
#   'CleanFee': 5,
#   'Dist': 4925,
#   'BA': 3,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 203,
#   'Price': 0,
#   'Name': 'Walk to Tulane, The Purple Room of the Treehouse',
#   'Polarity': 4905},
#  {'MinNights': 1,
#   'Hood': 40,
#   'SqFt': 11,
#   '#Reviews': 113,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 21,
#   'CleanFee': 48,
#   'Dist': 4607,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 153,
#   'Price': 1,
#   'Name': 'Artist, LGBTQ, pet friendly, NOLA!',
#   'Polarity': 5196},
#  {'MinNights': 2,
#   'Hood': 67,
#   'SqFt': 20,
#   '#Reviews': 14,
#   '#Guests': 4,
#   'Listing Count': 1,
#   'Security': 28,
#   'CleanFee': 69,
#   'Dist': 5755,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 5,
#   '#Booked': 22,
#   'Price': 3,
#   'Name': 'AUDUBON RIVERSIDE UPTOWN 2BR (Lic: 18STR-12860)',
#   'Polarity': 538},
#  {'MinNights': 1,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 45,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 52,
#   'CleanFee': 90,
#   'Dist': 2025,
#   'BA': 4,
#   'BR': 5,
#   'Beds': 6,
#   'Acc': 10,
#   '#Booked': 61,
#   'Price': 3,
#   'Name': 'Modern Home Near French Quarter',
#   'Polarity': 4128},
#  {'MinNights': 3,
#   'Hood': 56,
#   'SqFt': 20,
#   '#Reviews': 109,
#   '#Guests': 2,
#   'Listing Count': 1,
#   'Security': 8,
#   'CleanFee': 51,
#   'Dist': 3923,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 148,
#   'Price': 1,
#   'Name': 'Lower Garden District Apartment',
#   'Polarity': 5033},
#  {'MinNights': 3,
#   'Hood': 51,
#   'SqFt': 20,
#   '#Reviews': 35,
#   '#Guests': 3,
#   'Listing Count': 2,
#   'Security': 18,
#   'CleanFee': 69,
#   'Dist': 1372,
#   'BA': 3,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 5,
#   '#Booked': 55,
#   'Price': 2,
#   'Name': 'Stunning Villa Just Steps to the French Quarter!',
#   'Polarity': 2812},
#  {'MinNights': 1,
#   'Hood': 51,
#   'SqFt': 20,
#   '#Reviews': 197,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 18,
#   'CleanFee': 34,
#   'Dist': 965,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 303,
#   'Price': 2,
#   'Name': 'Garden Studio in a Historic Home',
#   'Polarity': 2827},
#  {'MinNights': 0,
#   'Hood': 1,
#   'SqFt': 20,
#   '#Reviews': 38,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 0,
#   'Dist': 5020,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 3,
#   '#Booked': 52,
#   'Price': 2,
#   'Name': 'TULANE/LOYOLA U,Streetcar, Pool .1-2  Bdrm/Bath',
#   'Polarity': 5416},
#  {'MinNights': 1,
#   'Hood': 54,
#   'SqFt': 20,
#   '#Reviews': 89,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 28,
#   'CleanFee': 0,
#   'Dist': 3507,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 2,
#   '#Booked': 123,
#   'Price': 1,
#   'Name': 'Cozy and Eclectic in the Bywater',
#   'Polarity': 5320},
#  {'MinNights': 2,
#   'Hood': 8,
#   'SqFt': 20,
#   '#Reviews': 253,
#   '#Guests': 0,
#   'Listing Count': 3,
#   'Security': 0,
#   'CleanFee': 34,
#   'Dist': 3346,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 389,
#   'Price': 1,
#   'Name': '3 blocks from the St. Charles streetcar!',
#   'Polarity': 4840},
#  {'MinNights': 1,
#   'Hood': 54,
#   'SqFt': 20,
#   '#Reviews': 122,
#   '#Guests': 2,
#   'Listing Count': 1,
#   'Security': 8,
#   'CleanFee': 48,
#   'Dist': 2867,
#   'BA': 1,
#   'BR': 3,
#   'Beds': 5,
#   'Acc': 7,
#   '#Booked': 165,
#   'Price': 2,
#   'Name': 'Heart of Bywater 3 bedroom Guest House',
#   'Polarity': 3430},
#  {'MinNights': 2,
#   'Hood': 9,
#   'SqFt': 20,
#   '#Reviews': 22,
#   '#Guests': 3,
#   'Listing Count': 2,
#   'Security': 26,
#   'CleanFee': 34,
#   'Dist': 3949,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 30,
#   'Price': 2,
#   'Name': 'The Cottage - NOLA headquarters!!',
#   'Polarity': 4758},
#  {'MinNights': 2,
#   'Hood': 51,
#   'SqFt': 20,
#   '#Reviews': 157,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 2,
#   'CleanFee': 48,
#   'Dist': 1651,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 212,
#   'Price': 1,
#   'Name': 'Airy, Spacious, Close to the Action',
#   'Polarity': 4657},
#  {'MinNights': 2,
#   'Hood': 62,
#   'SqFt': 35,
#   '#Reviews': 66,
#   '#Guests': 0,
#   'Listing Count': 5,
#   'Security': 21,
#   'CleanFee': 64,
#   'Dist': 5000,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 5,
#   '#Booked': 124,
#   'Price': 2,
#   'Name': 'Uptown nola-close to parades & universities',
#   'Polarity': 4765},
#  {'MinNights': 1,
#   'Hood': 1,
#   'SqFt': 20,
#   '#Reviews': 41,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 15,
#   'CleanFee': 40,
#   'Dist': 4951,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 4,
#   '#Booked': 99,
#   'Price': 1,
#   'Name': 'TWO UPTOWN BEDROOMS share sitting area, sleeps 4',
#   'Polarity': 2400},
#  {'MinNights': 10,
#   'Hood': 19,
#   'SqFt': 20,
# ...
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 33,
#   'CleanFee': 103,
#   'Dist': 3019,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 4,
#   '#Booked': 14,
#   'Price': 1,
#   'Name': 'Spacious Victorian home in Bywater',
#   'Polarity': 5691},
#  {'MinNights': 1,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 89,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 48,
#   'Dist': 1621,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 215,
#   'Price': 2,
#   'Name': 'Half-double in the Marigny',
#   'Polarity': 3389},
#  {'MinNights': 0,
#   'Hood': 33,
#   'SqFt': 20,
#   '#Reviews': 96,
#   '#Guests': 0,
#   'Listing Count': 11,
#   'Security': 15,
#   'CleanFee': 23,
#   'Dist': 5685,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 233,
#   'Price': 1,
#   'Name': 'Sunny Spot - parking , 15 minutes drive to Fr. Qtr',
#   'Polarity': 2905},
#  {'MinNights': 1,
#   'Hood': 35,
#   'SqFt': 20,
#   '#Reviews': 95,
#   '#Guests': 1,
#   'Listing Count': 3,
#   'Security': 18,
#   'CleanFee': 34,
#   'Dist': 3092,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 262,
#   'Price': 2,
#   'Name': 'Courtyard Suite on Tchoupitoulas by Convention Ctr',
#   'Polarity': 4170},
#  {'MinNights': 0,
#   'Hood': 45,
#   'SqFt': 20,
#   '#Reviews': 1,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 2,
#   'CleanFee': 16,
#   'Dist': 5604,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 199,
#   'Price': 1,
#   'Name': 'Cozy private bedroom. Great neighborhood.',
#   'Polarity': 3732},
#  {'MinNights': 0,
#   'Hood': 58,
#   'SqFt': 20,
#   '#Reviews': 92,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 5,
#   'CleanFee': 27,
#   'Dist': 4807,
#   'BA': 3,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 5,
#   '#Booked': 247,
#   'Price': 1,
#   'Name': 'Beautiful uptown home',
#   'Polarity': 4968},
#  {'MinNights': 0,
#   'Hood': 52,
#   'SqFt': 20,
#   '#Reviews': 139,
#   '#Guests': 5,
#   'Listing Count': 2,
#   'Security': 15,
#   'CleanFee': 34,
#   'Dist': 5850,
#   'BA': 1,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 342,
#   'Price': 2,
#   'Name': 'Charming, Safe, Quiet Lakeview Home',
#   'Polarity': 1116},
#  {'MinNights': 1,
#   'Hood': 2,
#   'SqFt': 20,
#   '#Reviews': 43,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 55,
#   'Dist': 2523,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 5,
#   '#Booked': 117,
#   'Price': 2,
#   'Name': "Nice apartment in our artist's complex",
#   'Polarity': 1462},
#  {'MinNights': 1,
#   'Hood': 67,
#   'SqFt': 20,
#   '#Reviews': 49,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 2,
#   'CleanFee': 34,
#   'Dist': 5325,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 4,
#   '#Booked': 120,
#   'Price': 1,
#   'Name': 'Private House in Perfect Uptown Spot',
#   'Polarity': 2545},
#  {'MinNights': 0,
#   'Hood': 40,
#   'SqFt': 20,
#   '#Reviews': 49,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 54,
#   'Dist': 4201,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 122,
#   'Price': 2,
#   'Name': 'Magic in MidCity:  Mardi Gras & Jazz fest',
#   'Polarity': 3361},
#  {'MinNights': 2,
#   'Hood': 42,
#   'SqFt': 20,
#   '#Reviews': 71,
#   '#Guests': 2,
#   'Listing Count': 14,
#   'Security': 33,
#   'CleanFee': 60,
#   'Dist': 5712,
#   'BA': 1,
#   'BR': 3,
#   'Beds': 5,
#   'Acc': 6,
#   '#Booked': 174,
#   'Price': 1,
#   'Name': 'The Orange Buddha, 3 bedrooms!',
#   'Polarity': 2520},
#  {'MinNights': 0,
#   'Hood': 7,
#   'SqFt': 20,
#   '#Reviews': 104,
#   '#Guests': 1,
#   'Listing Count': 11,
#   'Security': 18,
#   'CleanFee': 34,
#   'Dist': 550,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 257,
#   'Price': 3,
#   'Name': 'Ultra Modern Downtown Apartment B',
#   'Polarity': 2257},
#  {'MinNights': 0,
#   'Hood': 7,
#   'SqFt': 20,
#   '#Reviews': 43,
#   '#Guests': 3,
#   'Listing Count': 11,
#   'Security': 18,
#   'CleanFee': 54,
#   'Dist': 738,
#   'BA': 4,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 6,
#   '#Booked': 113,
#   'Price': 2,
#   'Name': 'Comfortable Ultra Modern Downtown Apartment',
#   'Polarity': 424},
#  {'MinNights': 1,
#   'Hood': 27,
#   'SqFt': 20,
#   '#Reviews': 161,
#   '#Guests': 5,
#   'Listing Count': 2,
#   'Security': 38,
#   'CleanFee': 78,
#   'Dist': 4404,
#   'BA': 4,
#   'BR': 3,
#   'Beds': 5,
#   'Acc': 6,
#   '#Booked': 399,
#   'Price': 2,
#   'Name': 'Garden District 3bd with Parking',
#   'Polarity': 4197},
#  {'MinNights': 2,
#   'Hood': 54,
#   'SqFt': 20,
#   '#Reviews': 182,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 55,
#   'Dist': 3063,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 448,
#   'Price': 0,
#   'Name': 'Sanctuary Between Piety & Desire',
#   'Polarity': 4373},
#  {'MinNights': 1,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 103,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 34,
#   'Dist': 1010,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 249,
#   'Price': 2,
#   'Name': 'La Casa de Mojo',
#   'Polarity': 3349},
#  {'MinNights': 2,
#   'Hood': 20,
#   'SqFt': 20,
#   '#Reviews': 75,
#   '#Guests': 3,
#   'Listing Count': 2,
#   'Security': 8,
#   'CleanFee': 103,
#   'Dist': 3973,
#   'BA': 4,
#   'BR': 2,
#   'Beds': 6,
#   'Acc': 10,
#   '#Booked': 183,
#   'Price': 2,
#   'Name': 'Garden District-2 miles to French Quarter-Parking',
#   'Polarity': 1634},
#  {'MinNights': 1,
#   'Hood': 15,
#   'SqFt': 20,
#   '#Reviews': 147,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 2,
#   'CleanFee': 27,
#   'Dist': 4001,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 354,
#   'Price': 1,
#   'Name': 'PrivateHome/2mi to frenQuarter/ 0.5 mi>City Park',
#   'Polarity': 4734},
#  {'MinNights': 0,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 187,
#   '#Guests': 0,
#   'Listing Count': 5,
#   'Security': 2,
#   'CleanFee': 23,
#   'Dist': 693,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 455,
#   'Price': 1,
#   'Name': 'Sweet Suite in Historic Treme',
#   'Polarity': 2589},
#  {'MinNights': 0,
#   'Hood': 8,
#   'SqFt': 20,
#   '#Reviews': 141,
#   '#Guests': 0,
#   'Listing Count': 4,
#   'Security': 21,
#   'CleanFee': 42,
#   'Dist': 2347,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 343,
#   'Price': 2,
#   'Name': 'Modern Luxury on Streetcar Line',
#   'Polarity': 3927},
#  {'MinNights': 2,
#   'Hood': 2,
#   'SqFt': 20,
#   '#Reviews': 5,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 55,
#   'Dist': 2456,
#   'BA': 4,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 6,
#   '#Booked': 15,
#   'Price': 3,
#   'Name': 'Beautiful Bayou St. John unit, JAZZ FEST!',
#   'Polarity': 599},
#  {'MinNights': 2,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 74,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 2,
#   'CleanFee': 34,
#   'Dist': 1062,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 179,
#   'Price': 2,
#   'Name': 'Heart of the Marigny Triangle',
#   'Polarity': 4485},
#  {'MinNights': 2,
#   'Hood': 51,
#   'SqFt': 20,
#   '#Reviews': 212,
#   '#Guests': 0,
#   'Listing Count': 2,
#   'Security': 8,
#   'CleanFee': 40,
#   'Dist': 1341,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 518,
#   'Price': 1,
#   'Name': 'Cool Private Suite in South 7th Ward',
#   'Polarity': 5122},
#  {'MinNights': 0,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 221,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 21,
#   'Dist': 1838,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 2,
#   '#Booked': 671,
#   'Price': 1,
#   'Name': 'Tranquil Treme Guest House - min to French Quarter',
#   'Polarity': 4732},
#  {'MinNights': 1,
#   'Hood': 8,
#   'SqFt': 20,
#   '#Reviews': 61,
#   '#Guests': 1,
#   'Listing Count': 3,
#   'Security': 18,
#   'CleanFee': 34,
#   'Dist': 3505,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 149,
#   'Price': 1,
#   'Name': 'Private Courtyard Apartment',
#   'Polarity': 4458},
#  {'MinNights': 2,
#   'Hood': 6,
#   'SqFt': 20,
#   '#Reviews': 71,
#   '#Guests': 5,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 103,
#   'Dist': 2946,
#   'BA': 4,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 7,
#   '#Booked': 178,
#   'Price': 3,
#   'Name': 'Beautiful and Spacious Bywater Home',
#   'Polarity': 4778},
#  {'MinNights': 2,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 63,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 51,
#   'Dist': 857,
#   'BA': 1,
#   'BR': 0,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 154,
#   'Price': 2,
#   'Name': 'Charming New Orleans Cottage',
#   'Polarity': 5265},
#  {'MinNights': 2,
#   'Hood': 58,
#   'SqFt': 0,
#   '#Reviews': 172,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 21,
#   'CleanFee': 40,
#   'Dist': 5095,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 420,
#   'Price': 1,
#   'Name': 'COZY Private Magazine St. Apartment (4-guests)',
#   'Polarity': 5250},
#  {'MinNights': 1,
#   'Hood': 14,
#   'SqFt': 20,
#   '#Reviews': 14,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 15,
#   'CleanFee': 60,
#   'Dist': 5136,
#   'BA': 4,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 4,
#   '#Booked': 35,
#   'Price': 2,
#   'Name': 'Great location - Renovated Shotgun',
#   'Polarity': 911},
#  {'MinNights': 1,
#   'Hood': 37,
#   'SqFt': 20,
#   '#Reviews': 110,
#   '#Guests': 1,
#   'Listing Count': 4,
#   'Security': 26,
#   'CleanFee': 69,
#   'Dist': 958,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 270,
#   'Price': 2,
#   'Name': 'The Border to the Quarter Unit 2',
#   'Polarity': 2965},
#  {'MinNights': 2,
#   'Hood': 13,
#   'SqFt': 20,
#   '#Reviews': 7,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 2,
#   'CleanFee': 85,
#   'Dist': 5215,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 19,
#   'Price': 2,
#   'Name': 'Hillary Gardens Uptown/University',
#   'Polarity': 5176},
#  {'MinNights': 1,
#   'Hood': 0,
#   'SqFt': 20,
#   '#Reviews': 202,
#   '#Guests': 1,
#   'Listing Count': 3,
#   'Security': 0,
#   'CleanFee': 42,
#   'Dist': 2040,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 4,
#   'Acc': 2,
#   '#Booked': 513,
#   'Price': 0,
#   'Name': 'Contemporary Algiers Point Loft - Lic# 18STR-16344',
#   'Polarity': 3687},
#  {'MinNights': 1,
#   'Hood': 35,
#   'SqFt': 20,
#   '#Reviews': 35,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 55,
#   'Dist': 1797,
#   'BA': 1,
#   'BR': 0,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 90,
#   'Price': 2,
#   'Name': 'Loft/art studio in Warehouse Dist.',
#   'Polarity': 878},
#  {'MinNights': 0,
#   'Hood': 40,
#   'SqFt': 20,
#   '#Reviews': 67,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 0,
#   'Dist': 4664,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 463,
#   'Price': 0,
#   'Name': 'Private Mid-City Suite near Canal Streetcar',
#   'Polarity': 3689},
#  {'MinNights': 0,
#   'Hood': 51,
#   'SqFt': 20,
#   '#Reviews': 117,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 38,
#   'CleanFee': 48,
#   'Dist': 2235,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 6,
#   '#Booked': 305,
#   'Price': 0,
#   'Name': 'Cozy Private Entrance Sleeps 6 Comfortably',
#   'Polarity': 2653},
#  {'MinNights': 1,
#   'Hood': 8,
#   'SqFt': 20,
#   '#Reviews': 168,
#   '#Guests': 0,
#   'Listing Count': 3,
#   'Security': 18,
#   'CleanFee': 9,
#   'Dist': 3414,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 408,
#   'Price': 0,
#   'Name': 'Room near historic St Charles Ave',
#   'Polarity': 4274},
#  {'MinNights': 0,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 262,
#   '#Guests': 0,
#   'Listing Count': 5,
#   'Security': 18,
#   'CleanFee': 34,
#   'Dist': 1276,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 5,
#   'Acc': 4,
#   '#Booked': 659,
#   'Price': 1,
#   'Name': 'Lovely Historic Home in the Treme',
#   'Polarity': 2041},
#  {'MinNights': 1,
#   'Hood': 51,
#   'SqFt': 20,
#   '#Reviews': 171,
#   '#Guests': 1,
#   'Listing Count': 8,
#   'Security': 0,
#   'CleanFee': 21,
#   'Dist': 1702,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 4,
#   '#Booked': 423,
#   'Price': 2,
#   'Name': 'Modern Condo III Block From Quarter',
#   'Polarity': 1233},
#  {'MinNights': 1,
#   'Hood': 35,
#   'SqFt': 20,
#   '#Reviews': 72,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 38,
#   'CleanFee': 55,
#   'Dist': 3368,
#   'BA': 4,
#   'BR': 1,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 179,
#   'Price': 3,
#   'Name': 'Garden District Carriage House with Pool / Hot Tub',
#   'Polarity': 5222},
#  {'MinNights': 2,
#   'Hood': 54,
#   'SqFt': 20,
#   '#Reviews': 129,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 40,
#   'Dist': 2970,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 4,
#   '#Booked': 318,
#   'Price': 2,
#   'Name': 'relaxing Bywater retreat',
#   'Polarity': 4114},
#  {'MinNights': 1,
#   'Hood': 41,
#   'SqFt': 20,
#   '#Reviews': 27,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 15,
#   'CleanFee': 34,
#   'Dist': 4554,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 4,
#   '#Booked': 73,
#   'Price': 2,
#   'Name': 'New Orleans Vacation Getaway',
#   'Polarity': 1638},
#  {'MinNights': 0,
#   'Hood': 62,
#   'SqFt': 20,
#   '#Reviews': 42,
#   '#Guests': 1,
#   'Listing Count': 1,
#   'Security': 8,
#   'CleanFee': 48,
#   'Dist': 5466,
#   'BA': 1,
#   'BR': 0,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 105,
#   'Price': 1,
#   'Name': 'Uptown/St Charles /Magazine best location & Price',
#   'Polarity': 2801},
#  {'MinNights': 2,
#   'Hood': 41,
#   'SqFt': 20,
#   '#Reviews': 70,
#   '#Guests': 9,
#   'Listing Count': 1,
#   'Security': 44,
#   'CleanFee': 0,
#   'Dist': 4343,
#   'BA': 7,
#   'BR': 5,
#   'Beds': 6,
#   'Acc': 10,
#   '#Booked': 183,
#   'Price': 4,
#   'Name': '3 story historic Home-Uptown',
#   'Polarity': 5016},
#  {'MinNights': 1,
#   'Hood': 55,
#   'SqFt': 20,
#   '#Reviews': 204,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 18,
#   'CleanFee': 13,
#   'Dist': 2557,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 506,
#   'Price': 1,
#   'Name': 'Spacious 2 Bdrm in Saint Roch! New Orleans',
#   'Polarity': 1660},
#  {'MinNights': 1,
#   'Hood': 51,
#   'SqFt': 20,
#   '#Reviews': 34,
#   '#Guests': 3,
#   'Listing Count': 2,
#   'Security': 0,
#   'CleanFee': 54,
#   'Dist': 2423,
#   'BA': 4,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 90,
#   'Price': 2,
#   'Name': 'A Real Gem in the Heart of Gentilly',
#   'Polarity': 3178},
#  {'MinNights': 0,
#   'Hood': 55,
#   'SqFt': 20,
#   '#Reviews': 199,
#   '#Guests': 1,
#   'Listing Count': 3,
#   'Security': 0,
#   'CleanFee': 30,
#   'Dist': 2174,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 4,
#   '#Booked': 493,
#   'Price': 2,
#   'Name': 'Lofty New Marigny Master w/ Bath',
#   'Polarity': 2668},
#  {'MinNights': 1,
#   'Hood': 51,
#   'SqFt': 20,
#   '#Reviews': 161,
#   '#Guests': 1,
#   'Listing Count': 5,
#   'Security': 8,
#   'CleanFee': 37,
#   'Dist': 2653,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 397,
#   'Price': 1,
#   'Name': 'Lovely Mid City Home',
#   'Polarity': 801},
#  {'MinNights': 2,
#   'Hood': 9,
#   'SqFt': 20,
#   '#Reviews': 0,
#   '#Guests': 7,
#   'Listing Count': 1,
#   'Security': 21,
#   'CleanFee': 69,
#   'Dist': 3795,
#   'BA': 3,
#   'BR': 3,
#   'Beds': 4,
#   'Acc': 8,
#   '#Booked': 22,
#   'Price': 4,
#   'Name': 'Walk to VooDoo festival and on the streetcar line',
#   'Polarity': 1247},
#  {'MinNights': 0,
#   'Hood': 6,
#   'SqFt': 20,
#   '#Reviews': 68,
#   '#Guests': 0,
#   'Listing Count': 1,
#   'Security': 0,
#   'CleanFee': 81,
#   'Dist': 2088,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 7,
#   'Acc': 6,
#   '#Booked': 178,
#   'Price': 1,
#   'Name': '2 Bedroom Cozy Shotgun Marigny House!',
#   'Polarity': 1816},
#  {'MinNights': 10,
#   'Hood': 6,
#   'SqFt': 20,
#   '#Reviews': 36,
#   '#Guests': 1,
#   'Listing Count': 5,
#   'Security': 0,
#   'CleanFee': 45,
#   'Dist': 2625,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 89,
#   'Price': 2,
#   'Name': 'Laid Back Charm 2 Bywater Marigny',
#   'Polarity': 2333},
#  {'MinNights': 2,
#   'Hood': 6,
#   'SqFt': 20,
#   '#Reviews': 51,
#   '#Guests': 1,
#   'Listing Count': 2,
#   'Security': 18,
#   'CleanFee': 34,
#   'Dist': 2046,
#   'BA': 1,
#   'BR': 1,
#   'Beds': 1,
#   'Acc': 2,
#   '#Booked': 131,
#   'Price': 1,
#   'Name': 'Sunny, Marigny Parlor Apartment',
#   'Polarity': 4920},
#  {'MinNights': 1,
#   'Hood': 2,
#   'SqFt': 20,
#   '#Reviews': 89,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 8,
#   'CleanFee': 48,
#   'Dist': 2575,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 220,
#   'Price': 2,
#   'Name': 'Bayou St. John Charmer',
#   'Polarity': 4697},
#  {'MinNights': 0,
#   'Hood': 6,
#   'SqFt': 20,
#   '#Reviews': 32,
#   '#Guests': 3,
#   'Listing Count': 1,
#   'Security': 15,
#   'CleanFee': 40,
#   'Dist': 3672,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 2,
#   'Acc': 4,
#   '#Booked': 80,
#   'Price': 1,
#   'Name': 'Classic Charm in Bywater',
#   'Polarity': 3074},
#  ...]

# %%
# myquery1={}
myquery1 = {"Name":{ '$eq': ('Treme Two Bedroom Suite - French Quarter Access') }}

listings1=[]
for json1 in collection.find(myquery1):
    data1 = {}
    data1.update({
    'MinNights': json['MinNights'],
    'Hood' : json['Hood'],
    'SqFt' : json['SqFt'],
    '#Reviews': json['#Reviews'],
    '#Guests' :json['#Guests'],
    'Listing Count' : json['Listing Count'],
    'Security':json['Security']      ,
    'CleanFee':json['CleanFee'],
    'Dist':json['Dist'],
    'BA':json['BA'],
    'BR':json['BR'],
    'Beds':json['Beds'],
    'Acc': json['Acc'],
    '#Booked':json['#Booked'],
    'Price':json['Price'],
    'Name':json['Name'],
                'Polarity':json['Polarity']

    })
#     listings.append(data)
    listings1.append(data1)
listings1
# Out:
# [{'MinNights': 1,
#   'Hood': 59,
#   'SqFt': 20,
#   '#Reviews': 0,
#   '#Guests': 3,
#   'Listing Count': 2,
#   'Security': 0,
#   'CleanFee': 40,
#   'Dist': 1839,
#   'BA': 1,
#   'BR': 2,
#   'Beds': 4,
#   'Acc': 4,
#   '#Booked': 99,
#   'Price': 0,
#   'Name': 'Treme Two Bedroom Suite - French Quarter Access',
#   'Polarity': 118}]

# %%
test = pd.DataFrame(listings)
test1 = pd.DataFrame(listings1)
x1 = test.drop('Price', axis=1)
x = x1.drop('Name', axis=1)
y = test['Price']
print(x, y)
# Out:
#       #Booked  #Guests  #Reviews  Acc  BA  BR  Beds  CleanFee  Dist  Hood  \
# 0          98        3        95    4   4   3     4        69  5069    43
# 1         398        1       287    3   1   1     1        40  4988    33
# 2         209        1       214    2   1   1     1        55  1422    37
# 3         131        1       132    2   4   1     1        48  3255    54
# 4         175        1       178    2   1   1     1        34  4128     6
# 5         192        1       190    2   1   1     1        55  2481     2
# 6         206        1       200    2   1   1     1        55  3522    54
# 7         454        1       289    2   1   1     1        23  2012    55
# 8         223        0       165    2   1   1     1        16  3504     6
# 9         438        2       284    5   1   2     4        13  2468    51
# 10         31        0        26    2   1   1     1        55  4720    38
# 11        289        1       251    4   1   2     2        40  3468    54
# 12        598        1       302    2   4   1     1         5  1187    37
# 13         49        2        32    4   1   2     4        69  5362    57
# 14         54        1        30    2   1   1     1        69  5399    57
# 15        575        0       300    2   1   1     1        27   855    59
# 16          5        0         4    4   1   0     1         0  3271     8
# 17        355        1       270    2   1   1     1        27   913    37
# 18        147        1       133    3   1   1     1         0  4040    40
# 19        105        2       100    2   4   1     1        88  3079     6
# 20        514        1       296    2   1   1     1        30   537    59
# 21         90        0        86    2   1   1     1        55  4245     6
# 22        494        0       293    2   1   1     1        30   845    59
# 23        318        1       256    4   1   2     2        40  2953    54
# 24        499        1       292    2   1   1     1        30   678    59
# 25        613        1       301    2   4   1     1         5  1171    37
# 26        175        3       158    4   5   2     2        51   504    59
# 27        262        3       226    4   5   2     2        85   463    59
# 28        175        0       129    2   1   1     1        34  3598     9
# 29         80        1        72    2   1   1     2        55  5738     4
# ...       ...      ...       ...  ...  ..  ..   ...       ...   ...   ...
# 5989       99        0         0    6   4   2     2         0  1433     7
# 5990      299        2         2    4   1   0     1        13  3586     8
# 5991       99        0         0    4   4   1     2        88  4476    27
# 5992       99        0         0    2   1   1     1        55  3224    35
# 5993       99        1         0    2   1   1     1        69  5033    21
# 5994       99        0         0    4   1   1     2        55  5847    67
# 5995       99        0         0    2   1   1     1        40  5334    25
# 5996       99        0         0    4   3   3     5         5  5477    25
# 5997       99        1         0    2   1   1     2        45  2502    51
# 5998       99        1         0    2   1   1     1         0  5533    33
# 5999       99        1         0    3   3   1     2        21  5925    34
# 6000       99        0         0    6   1   2     4        60  2750     2
# 6001       99        0         0    3   1   2     1        45  5196    62
# 6002       99        0         0    6   4   3     5       120  3970     5
# 6003       99        4         0    4   4   2     2        27  2645     8
# 6004       99        0         0    2   1   1     1        55  4493     9
# 6005       99        0         0    1   1   1     1        55  4437    40
# 6006       99        1         0    4   4   2     2        13  5620    21
# 6007       99        0         0    2   1   1     1        21  2545     8
# 6008       99        0         0    2   1   1     1        27  3565    15
# 6009       99        5         0    6   1   1     1        40  5974    34
# 6010       99        3         0    7   5   2     6       103  3010     6
# 6011       99        0         0   11   1   3     6       103  3811    17
# 6012       99        0         0    4   4   2     2        55  2308    60
# 6013       99        0         0    6   3   2     4       120   236    59
# 6014       99        0         0    6   4   3     5       113  3705    68
# 6015       99        0         0    6   1   2     4        69  1502    60
# 6016       99        2         0    3   1   1     2        69  4254    27
# 6017       99        0         0    2   1   1     1        27   710    59
# 6018       99        3         0    4   1   2     4        40  1839    59
#
#       Listing Count  MinNights  Polarity  Security  SqFt
# 0                 1          1      4601         0    20
# 1                 1          0      4272         0    15
# 2                 2          3      5192        18    20
# 3                 2          2      5279         0    20
# 4                 2          4      5326        15    20
# 5                 2          1      5123        18     7
# 6                 1          2      5398        18    20
# 7                 3          2      5314        21    20
# 8                 2          2      4751        18    20
# 9                 1          3      3537        15    20
# 10                1          2      2922        18    30
# 11                1          2      5188         0    10
# 12                3          0      3943         0    12
# 13                2          3      1464        55    20
# 14                2          2      2754        44    20
# 15                4          0      3978         8    12
# 16               37          1        68         0    10
# 17                2          2      4865         0    20
# 18                1          3      5255         0    20
# 19               11          3      4286        38    24
# 20                4          0      4090         8    20
# 21                2          3      4862         2    20
# 22                4          0      4415         8    20
# 23                3          3      4493        18    20
# 24                4          0      4276         8    12
# 25                3          0      4132         0    12
# 26                3          2      3431         8    20
# 27                3          2      4355         8    20
# 28                1          0      4868        18    20
# 29                1          1      5427        18    20
# ...             ...        ...       ...       ...   ...
# 5989              1          0      5824         0    20
# 5990              5          0       421         2    20
# 5991              1          2      5324        18    20
# 5992              1          1      5727        18    20
# 5993              1          1      5820        38    20
# 5994              1          0      1545        18    20
# 5995              1          0      2451        18    20
# 5996              2          0      5544         0    20
# 5997              5          2      5794        15    20
# 5998              1          1        16         2    20
# 5999              2          1      1170         0    20
# 6000              1          1      5343        15    20
# 6001              1          0       439        18    20
# 6002              1          1      3526        15    20
# 6003              1          0      5717         0    20
# 6004              1          0      5535        18    20
# 6005              1          3      4888        18    20
# 6006              1          1        16        15    20
# 6007              1          1      2558        18    20
# 6008              1          2      5448        18    20
# 6009              7          0      3917         2    20
# 6010              1          1      2712        15    20
# 6011              2          1      5088         8    20
# 6012              1          1       409        18    20
# 6013              3          1       719        15    20
# 6014              2          0      5704        15    20
# 6015              2          1      3067        18    20
# 6016              4          1       346        26    20
# 6017              6          1        25         2    20
# 6018              2          1       118         0    20
#
# [6019 rows x 15 columns] 0       3
# 1       1
# 2       2
# 3       1
# 4       0
# 5       2
# 6       2
# 7       1
# 8       1
# 9       1
# 10      1
# 11      1
# 12      1
# 13      2
# 14      1
# 15      1
# 16      3
# 17      2
# 18      1
# 19      2
# 20      1
# 21      0
# 22      1
# 23      1
# 24      1
# 25      1
# 26      2
# 27      2
# 28      1
# 29      1
#        ..
# 5989    4
# 5990    2
# 5991    3
# 5992    2
# 5993    2
# 5994    2
# 5995    1
# 5996    1
# 5997    2
# 5998    1
# 5999    1
# 6000    1
# 6001    1
# 6002    2
# 6003    1
# 6004    2
# 6005    1
# 6006    1
# 6007    1
# 6008    2
# 6009    2
# 6010    2
# 6011    3
# 6012    2
# 6013    2
# 6014    2
# 6015    3
# 6016    2
# 6017    2
# 6018    0
# Name: Price, Length: 6019, dtype: int64

# %%
x2=test1.drop('Name', axis=1)
x1 = x2.drop('Price', axis=1)
y1 = test1['Price']

# %%
print(x1)
# Out:
#    #Booked  #Guests  #Reviews  Acc  BA  BR  Beds  CleanFee  Dist  Hood  \
# 0       99        3         0    4   1   2     4        40  1839    59
#
#    Listing Count  MinNights  Polarity  Security  SqFt
# 0              2          1       118         0    20

# %%
from keras.models import load_model
# model=load_model("reviews.h5")
tf.keras.models.load_model(
    'reviews.h5',
    
)
# clf = RandomForestClassifier(n_estimators=11)
# scoring = 'accuracy'
# score = cross_val_score(clf, x1, y1, cv=k_fold, n_jobs=1, scoring=scoring)
# clf.fit(x1,y1)
# pred=()
# prediction1=clf.predict(x)
prediction1=model.predict(x1[0])
print(prediction1)
if prediction1[0] < y[0]:
    pred='Great Deal!'
if prediction1[0]==y[0]:
    pred='Right on the money!'
if prediction1[0] >y[0]:
    pred='Bad Deal'
prediction2=pd.DataFrame({"pred":pred, 'modl':prediction1[0],"sample":y})
prediction=prediction2.to_json(orient="records")
prediction2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-f9e9aa5512e7> in <module>
#       2 # model=load_model("reviews.h5")
#       3 tf.keras.models.load_model(
# ----> 4     'reviews.h5',
#       5
#       6 )
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     230     model_config = f.attrs.get('model_config')
#     231     if model_config is None:
# --> 232       raise ValueError('No model found in config file.')
#     233     model_config = json.loads(model_config.decode('utf-8'))
#     234     model = model_from_config(model_config, custom_objects=custom_objects)
#
# ValueError: No model found in config file.
